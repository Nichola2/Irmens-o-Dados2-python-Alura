# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(10)
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
# 5  2025.0          EN       FT       Data Engineer    80000   USD   80000
# 6  2025.0          SE       FT      Data Scientist   185000   USD  185000
# 7  2025.0          SE       FT      Data Scientist   148000   USD  148000
# 8  2025.0          MI       FT      Data Scientist   135000   USD  135000
# 9  2025.0          MI       FT      Data Scientist   108000   USD  108000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133349 non-null  object
#  2   contrato         133349 non-null  object
#  3   cargo            133349 non-null  object
#  4   salario          133349 non-null  int64
#  5   moeda            133349 non-null  object
#  6   usd              133349 non-null  int64
#  7   residencia       133349 non-null  object
#  8   remoto           133349 non-null  int64
#  9   empresa          133349 non-null  object
#  10  tamanho_empresa  133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#                  ano       salario            usd         remoto
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]

# %%
print("linhas:", linhas)
print("colunas:", colunas)
# Out:
# linhas: 133349
# colunas: 11

# %%
df.columns #tenho que resolver esse problema depois amanhã
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["nivel_experiencia"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nivel_experiencia'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2933530220.py in <cell line: 0>()
# ----> 1 df["nivel_experiencia"].value_counts()
#
# ...

# %%
# prompt: traduza para mim todas as colunas dos dataframe df para português brasileiro
renomear_colunas = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'

    }
df.rename(columns=renomear_colunas, inplace=True)
df.columns
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
renomear_colunas = {
    'ano': 'ano',
    'nivel_experiencia': 'senioridade',
    'tipo_emprego': 'contrato',
    'cargo': 'cargo',
    'salario': 'salario',
    'moeda_salario': 'moeda',
    'salario_em_usd': 'usd',
    'residencia_empregado': 'residencia',
    'taxa_remoto': 'remoto',
    'localizacao_empresa': 'empresa',
    'tamanho_empresa': 'tamanho_empresa'

    }
df.rename(columns=renomear_colunas, inplace=True)
df.columns
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["senioridade"].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["contrato"].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
df.describe(include="object")
# Out:
#        senioridade contrato           cargo   moeda residencia empresa  \
# count       133349   133349          133349  133349     133349  133349
# unique           4        4             390      26        102      95
# top             SE       FT  Data Scientist     USD         US      US
# freq         77241   132563           17314  126140     119579  119641
#
#        tamanho_empresa
# count           133349
# unique               3
# top                  M
# freq            129561

# %%
# @title Aula 1 - Análise de Dados com Pandas
df.describe()
# Out:
#                  ano       salario            usd         remoto
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
# @title Aula 2 - Preparação e limpeza dos Dados

df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade contrato                      cargo  salario moeda  \
# 5588    NaN          SE       FT            Product Manager   184500   USD
# 59692   NaN          MI       FT                   Engineer   110000   USD
# 59710   NaN          EN       FT             Data Scientist   208800   USD
# 59759   NaN          SE       FT          Software Engineer   135000   USD
# 59789   NaN          SE       FT                   Engineer   112000   USD
# 131000  NaN          SE       FT  Machine Learning Engineer   163800   USD
# 131006  NaN          SE       FT     Data Analytics Manager   204500   USD
# 133054  NaN          EN       FT             Data Scientist    40000   USD
# 133281  NaN          MI       FT  Machine Learning Engineer   180000   PLN
# 133317  NaN          MI       FT             Data Scientist   130000   USD
#
#            usd residencia  remoto empresa tamanho_empresa
# 5588    184500         US       0      US               M
# ...

# %%
import numpy as np
#A criação de um dataframe de teste para usar de exemplo
df_salarios = pd.DataFrame({
  'nomes': ['Ana','Bruno', 'Carlos', 'Daniele','Val'],
  'salario': [4000, np.nan, 5000, np.nan, 100000]
})
#Calcula a media e subistitui os nulos pela média e arredonda os valores
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))
''' Calcula a mediana e substitui os pela mediana'''

df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#      nomes   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
  "Dias": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta", ],
  "Temperaturas": [30, np.nan, np.nan, 28, 27]


})

df_temperaturas["Preenchido_ffill"] = df_temperaturas["Temperaturas"].ffill()
df_temperaturas
# Out:
#       Dias  Temperaturas  Preenchido_ffill
# 0  Segunda          30.0              30.0
# 1    Terça           NaN              30.0
# 2   Quarta           NaN              30.0
# 3   Quinta          28.0              28.0
# 4    Sexta          27.0              27.0

# %%
df_temperaturas = pd.DataFrame({
  "Dias": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta", ],
  "Temperaturas": [30, np.nan, np.nan, 28, 27]


})

df_temperaturas["Preenchido_bfill"] = df_temperaturas["Temperaturas"].bfill()
df_temperaturas
# Out:
#       Dias  Temperaturas  Preenchido_bfill
# 0  Segunda          30.0              30.0
# 1    Terça           NaN              28.0
# 2   Quarta           NaN              28.0
# 3   Quinta          28.0              28.0
# 4    Sexta          27.0              27.0

# %%
df_cidades = pd.DataFrame({
   'nomes': ['Ana','Bruno', 'Carlos', 'Daniele','Val'],
   "cidade": ["São Paulo", np.nan, "Curitiba", np.nan, "Belém"]

})

df_cidades["cidade_preenchida"] = df_cidades["cidade"].fillna("Não informado")
display(df_cidades)
# Out:
#      nomes     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  int64
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 12.2+ MB

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))

# %%
# @title Aula 3: Visualização de Dados

# %%
df_limpo.head()
# Out:
#     ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025          MI       FT       Data Engineer   158800   USD  158800
# 3  2025          MI       FT       Data Engineer   139200   USD  139200
# 4  2025          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
df_limpo['senioridade'].value_counts().plot(kind='bar', title="Distribuição de senioridade")
# Out:
# <Axes: title={'center': 'Distribuição de senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x="senioridade", y="usd")
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x="senioridade", y="usd")
plt.title("Salario médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salarios médi anual (USD)")
plt.show()

# %%
df_limpo.groupby("senioridade")["usd"].mean().sort_values(ascending=False)
# Out:
# senioridade
# EX    202027.667813
# SE    172850.838301
# MI    143044.845979
# EN     99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby("senioridade")["usd"].mean().sort_values(ascending=False).index

# %%
ordem
# Out:
# Index(['EX', 'SE', 'MI', 'EN'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x="senioridade", y="usd",order=ordem)
plt.title("Salario médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salarios médi anual (USD)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df_limpo['usd'], bins= 50, kde=True)
plt.title("Distribuição dos Salarios Anuais")
plt.xlabel("Salarios Em USD")
plt.ylabel("Frequência")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_limpo['usd'])
plt.title("Salarios")
plt.xlabel("Salarios Em USD")
plt.show()

# %%
ordem_senioridade = ['EX', 'SE', 'MI', 'EN']

plt.figure(figsize=(8,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade)
plt.title("Distribuição Salarial por Senioridade ")
plt.xlabel("Senioridade")
plt.ylabel("Salarios Em USD")
plt.show()

# %%
ordem_senioridade = ['EX', 'SE', 'MI', 'EN']

plt.figure(figsize=(8,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade, palette='Set2',hue='senioridade')
plt.title("Distribuição Salarial por Senioridade ")
plt.xlabel("Senioridade")
plt.ylabel("Salarios Em USD")
plt.show()

# %%
import plotly.express as px

# %%
#A IA é que fez tudo isso
df_avg_senioridade = df_limpo.groupby('senioridade')['usd'].mean().reset_index()

fig = px.bar(
    df_avg_senioridade,
    x='senioridade',
    y='usd',
    title='Média Salarial por Senioridade',
    labels={'senioridade': 'Senioridade', 'usd': 'Média Salarial Anual (USD)'},
    color='senioridade',
    color_discrete_sequence=px.colors.qualitative.Plotly
)

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagem,
    names='tipo_trabalho',
    values='quantidade',
    title='Porporção dos Tipos de Trabalhos]',

)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagem,
    names='tipo_trabalho',
    values='quantidade',
    title='Porporção dos Tipos de Trabalhos]',
    hole=0.5

)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagem,
    names='tipo_trabalho',
    values='quantidade',
    title='Porporção dos Tipos de Trabalhos]',
    hole=0.5
)

fig.update_traces(textinfo=('percent+label'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
# @title Aula 4 - Construindo um Dashboard com Streamlit

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 51.5 MB/s eta 0:00:00
# ...

# %%
import pycountry

# %%
import pycountry

# função para converter ISO-2 para ISO3
def iso2_to_iso3(code):
  try:
    return pycountry.countries.get(alpha_2=code).alpha_3
  except:
    return None
# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)
# Calcular média salarial por país (ISO -3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()
# Gera o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Média de Salário de Cientista de Dados por País',
                    labels={'usd': 'Salário Médio Anual (USD)', 'residencia_iso3': 'País'},
                    )
fig.update_layout(title_x=0.5, title_font_size=24)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025          MI       FT       Data Engineer   158800   USD  158800
# 3  2025          MI       FT       Data Engineer   139200   USD  139200
# 4  2025          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa residencia_iso3
# 0         US     100      US               M             USA
# 1         US     100      US               M             USA
# 2         AU       0      AU               M             AUS
# 3         AU       0      AU               M             AUS
# 4         US       0      US               M             USA

# %%
df_limpo.to_csv("dados-imersão-final", index=False)
